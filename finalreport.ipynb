# %% [markdown]
# # _Analysis of Toronto's centers of attractions for a stakeholder planing on building a hotel_

# %% [markdown]
# # Introduction:

# %% [markdown]
# background -
# Toronto, the capital of the province of Ontario, is a major Canadian city along Lake Ontario’s northwestern shore.
# It is a center of business and tourism, providing many opportunities for entrepreneurs.

# %% [markdown]
# the problem -
# a commercial group decided to build a new hotel in Toronto.
# they approached me in order to help them choose an optimal location for that hotel
#
# My working thesis is that in order to be attractive a hotel must have certain types of venues in it vicinity
# A well located hotel should have nearby food venues,
# as well as arts & entertainment venues for daily tourist activities
# and nightlife spots for those vacation wild nights.
#
# Another parameter that was considered was the number of hotels in its vicinity,
# now, this is tricky, because many hotels might mean high demand, but it also means alot of competition.

# %% [markdown]
# interest -
# in this project we will identify the neighborhoods that are centers of travelers activities in Toronto,
# we will then segment and cluster the different neighborhoods according to the above mentioned parameters
# (food, nightlife , arts & entertainment, hotels), try to characterize the clusters
# and find which neighborhood will be an optimal location for our new hotel.
#
# this analysis may be useful for any business in the tourism field,
# since it characterizes neighborhoods according to touristic points of interest.
# so it can show us, not only optimal locations for new hotels but also other touristic venues
# such as tourist shops, guided tour centers etc.
#
# it may also be used by tourist visiting Toronto to point them to areas of interest and help them choose where to stay.

# %% [markdown]
# # Data:

# %% [markdown]
# Data sources:

# %% [markdown]
# A list of Toronto's postal codes and neighborhoods scraped from wikipedia page :
# 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
# and their respective coordinates given on a .csv file in week 3 of this course

# %% [markdown]
# Foursquare API to find the arts & entertainment and food venus, nightlife spots and hotels in each neighborhood

# %%
from IPython.display import Image as IPythonImage

# %% [markdown]
# # Methodology:

# %% [markdown]
# The goal is to recommend areas that are suitable for a new hotel in Toronto
#
# I scraped from wikipedia a list of canada's postal codes and their respective boroughs and neighborhoods.
# Then I cleaned and arranged the data to make a dataframe of Toronto's postal codes with attributes -
# Borough, Neighborhood,   Latitude, Longitude.
#
# The dataframe was ilustrated on a folium map of toronto showing different postal codes and their respective neighborhoods

# %%
IPythonImage(filename='maptoronto1.jpg')

# %% [markdown]
# Foursquare was used for the analysis :
#
# First, I explored the first neighborhood in the dataframe, checking what food venues it has.
# After that, I defined functions to get from foursquare API arts & entertainment and food venues, nightlife spots and hotels.
# I grouped and counted the results by their attributes resulting in a dataframe showing the number of venues from each   attribute per neighborhood.

# %%
IPythonImage(filename='table2.jpg')

# %% [markdown]
# I then decided to use K-means to cluster the different neighborhoods by these attributes:

# %%
IPythonImage(filename='elbow3.jpg')

# %% [markdown]
# after testing I found that the optimal number of clusters is 2, I then explored the clusters and was able to characterize
# cluster 0 - neighborhoods with few to none art & entertainment venues, nightlife spots or hotels (food venues were basically everywhere)

# %%
IPythonImage(filename='cluster0.jpg')

# %% [markdown]
# cluster 1 - neighborhoods with high numbers of venues from all above types.
# from this we can deduce that cluster 0 is more residential or industrial neighborhoods and cluster 1 is more of centers of attractions

# %%
IPythonImage(filename='cluster1.jpg')

# %% [markdown]
# Displaying the clusters on a folium map of toronto reveals that all the neighborhoods in cluster 1 are located in the south center of the City which is it's cultural and nightlife center

# %%
IPythonImage(filename='map4.jpg')

# %% [markdown]
# Now we have cluster 1 as a list of recommended neighborhoods who have many places to eat,
# go out at night and get some culture during the day.
#
# We can further narrow the list according to additional requests,
# for example, neighborhoods with fewer number of hotels for less competition, or,
# neighborhoods with many nightlife spots to attract young travelers

# %% [markdown]
# Cluster 1 was filtered to give to five neighborhoods with the lowest number of hotels (>10)
# as these places have good potential and less competition for a new hotel

# %% [markdown]
# The results were displayed as dataframe and on a folium map

# %%
IPythonImage(filename='tabf.jpg')

# %%
IPythonImage(filename='mapf.jpg')

# %% [markdown]
# # Results:

# %% [markdown]
# We have searched for a good location for a new hotel in Toronto.
#
# we based our search on place with many food venues, arts & entertainment venues, nightlife spots and hotels
# during our analysis we found that although food venues are located all around the city,
# arts & entertainment and nightlife spots are situated mainly in south central Toronto.
#
# We checked further to see which neighborhoods that are rich in arts & entertainment and nightlife spots but have few hotels
# (in this project "few" was considered less then 10, fewer hotels means less competition)
# recieving a list of 5 neighborhoods that fit all parameters

# %% [markdown]
# # Discussion:

# %% [markdown]
# ### Observations:

# %% [markdown]
# During this analysis we found that the most attractive neighborhoods for tourists and travelers in Toronto
# are located in south central Toronto.
#
# this information might seem intuitive at first, but remember these results are based on data and therefore have validity
# we also found the borders of this so-called cultural center,
# and we didn't find any neighborhoods that shared these characteristics out of the south central zone

# %% [markdown]
# ### Recommendations:

# %%
IPythonImage(filename='barf.png')

# %% [markdown]
# If we further explore the list of 5 suitable neighborhoods, 2 stand out :
#
# * Berczy Park - having some Arts & Entertainment venues (7), food venues, many nightlife spots (28) but only 4 hotels
#
# * Harbourfront East, Toronto Islands, Union Station - having 9 hotels but the highest number of all other venues

# %% [markdown]
# If we can get data about how busy these hotels are we can apply a "competition rate" for each neighborhood
#
# "competition rate" = sum of scores of the hotels based on how busy they are
# this will give us information regarding demand for hotels in said neighborhood
# and will help us make a more calculated decision

# %% [markdown]
# # Conclusion:

# %% [markdown]
# Our goal was to recommend for a stake-holder attractive locations in Toronto for a new hotel.
#
# Using our data (geographical data and data obtained from foursquare API) we managed to define south central Toronto
# as the cultural center of the City (regarding arts, entertainment and food)
#
# In this center we searched for areas that do not have many hotels and produced a list of 5 such neighborhoods

# %% [markdown]
# From these 5 neighborhoods we managed to identify 2 as having the highest potential as a new hotel location :
#
# * Berczy Park (postal code M5E, downtown Toronto)
#
# * Harbourfront East, Toronto Islands, Union Station (postal code M5J, downtown Toronto)
